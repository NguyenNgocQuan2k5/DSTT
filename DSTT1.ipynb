# %%
import numpy as np
from random import randint
A = np.random.rand(3,3)
B = np.random.rand(3,3)
# Tổng 2 ma trận
TONG = A + B
# Hiệu 2 ma trận
HIEU = A - B
#Tích 2 ma trận
TICH = np.dot(A, B) 
# Tính tích Hadamard
HADAMARD = A * B
# Tính định thức ma trận
DET = np.linalg.det(A)
# Ma trận nghịch đảo
inv = np.linalg.inv(A)
# Ma trậ chuyển vị
A_T = A.T
# Ma trận nghịch đảo Moore-Penrose
A_pinv = np.linalg.pinv(A)
# Tính chuẩn Frobenius
frobenius_norm = np.linalg.norm(A, 'fro')
# Tính norm L1 và L2 mỗi hàng trong ma trận A
l1_norms = np.linalg.norm(A, ord=1, axis=1)
l2_norms = np.linalg.norm(A, ord=2, axis=1)
# Tìm ma trận con 2*2 ở góc trái A
submatrix = A[:2, :2]
# A.lamda
A_lamda = A * 2
# Ma trận đối xứng A^T.A
A_T_A = np.dot(A.T, A)
# Tính tổng các đường chéo trong ma trận
A_sum = np.trace(A)
# Tính các giá trị riêng và vertor riêng của A
eigenvalues, eigenvectors = np.linalg.eig(A)
# Kiểm tra ma trận có khả năng chéo hóa
eigenvalues, eigenvectors = np.linalg.eig(A)
eig_vec_matrix = np.array(eigenvectors)
if np.linalg.det(eig_vec_matrix) != 0:
    print("Ma trận A có thể chéo hóa.")
else:
    print("Ma trận A không thể chéo hóa.")
# Tạo ma trận C bằng kích thước 3*3 vs tất cả các phần tử bằng 1 ,và cộng vs ma trận A
C = np.ones((3, 3))
TONG = A + C
# Tạo ma trận đường chéo từ các phần tử của một vertor ngẫu nhiên 3*3
vector = np.random.rand(3)
diagonal_matrix = np.diag(vector)
# ma trận trực giao


# Tạo ma trận D ngẫu nhiên kích thước 4*4
D = np.random.rand(4,4)
# Ma trận khả nghịch
det_D = np.linalg.det(D)
if det_D != 0:
    print("Ma trận D là khả nghịch.")
else:
    print("Ma trận D không phải là khả nghịch.")
#Tính định thức ma trận
D = A.T.dot(B, A)
det_D = np.linalg.det(D)
# Tổng ma trận D vs ma trận I4 có cùng kích thước
I4 = np.eye(3)
TONG = D + I4
# Tạo ma trận F 3*3 các phần tử trong đường đéo chính là 1 vector ngậu nhiên
vector = np.random.rand(3)
F = np.diag(vector)
# kiểm tra ma trận chéo hóa
eigenvalues, eigenvectors = np.linalg.eig(F)
eig_vec_matrix = np.array(eigenvectors)
if np.linalg.det(eig_vec_matrix) != 0:
    print("Ma trận F có thể chéo hóa.")
else:
    print("Ma trận F không thể chéo hóa.")
#Tính tích của F vs ma trận đơn vị I3 và kiểm tra kết quả bằng F hay ko


# tính trace của ma trận F
trace_F = np.trace(F)
# Out:
# Ma trận A có thể chéo hóa.
# Ma trận D là khả nghịch.
